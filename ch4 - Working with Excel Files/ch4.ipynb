# %% [markdown]
# ### parsing Excel files

# %%
import openpyxl
import pprint

# %%
book = openpyxl.load_workbook('SOWC 2014 Stat Tables_Table 9.xlsx')

for sheet in book.sheetnames:
    print(sheet)
# Out:
# Data Notes
# Table 9

# %%
sheet = book['Table 9 ']
print(sheet)
# Out:
# <Worksheet "Table 9 ">

# %%
# let's explore what we can do with a sheet.
dir(sheet)
# Out:
# ['BREAK_COLUMN',
#  'BREAK_NONE',
#  'BREAK_ROW',
#  'HeaderFooter',
#  'ORIENTATION_LANDSCAPE',
#  'ORIENTATION_PORTRAIT',
#  'PAPERSIZE_A3',
#  'PAPERSIZE_A4',
#  'PAPERSIZE_A4_SMALL',
#  'PAPERSIZE_A5',
#  'PAPERSIZE_EXECUTIVE',
#  'PAPERSIZE_LEDGER',
#  'PAPERSIZE_LEGAL',
#  'PAPERSIZE_LETTER',
#  'PAPERSIZE_LETTER_SMALL',
#  'PAPERSIZE_STATEMENT',
#  'PAPERSIZE_TABLOID',
#  'SHEETSTATE_HIDDEN',
#  'SHEETSTATE_VERYHIDDEN',
#  'SHEETSTATE_VISIBLE',
#  '_WorkbookChild__title',
#  '__class__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_cell',
#  '_add_column',
#  '_add_row',
#  '_cells',
#  '_cells_by_col',
#  '_cells_by_row',
#  '_charts',
#  '_clean_merge_range',
#  '_comments',
#  '_current_row',
#  '_default_title',
#  '_drawing',
#  '_get_cell',
#  '_hyperlinks',
#  '_id',
#  '_images',
#  '_invalid_row',
#  '_move_cell',
#  '_move_cells',
#  '_parent',
#  '_path',
#  '_pivots',
#  '_print_area',
#  '_print_cols',
#  '_print_rows',
#  '_rel_type',
#  '_rels',
#  '_setup',
#  '_tables',
#  'active_cell',
#  'add_chart',
#  'add_data_validation',
#  'add_image',
#  'add_pivot',
#  'add_table',
#  'append',
#  'array_formulae',
#  'auto_filter',
#  'calculate_dimension',
#  'cell',
#  'col_breaks',
#  'column_dimensions',
#  'columns',
#  'conditional_formatting',
#  'data_validations',
#  'defined_names',
#  'delete_cols',
#  'delete_rows',
#  'dimensions',
#  'encoding',
#  'evenFooter',
#  'evenHeader',
#  'firstFooter',
#  'firstHeader',
#  'freeze_panes',
#  'insert_cols',
#  'insert_rows',
#  'iter_cols',
#  'iter_rows',
#  'legacy_drawing',
#  'max_column',
#  'max_row',
#  'merge_cells',
#  'merged_cell_ranges',
#  'merged_cells',
#  'mime_type',
#  'min_column',
#  'min_row',
#  'move_range',
#  'oddFooter',
#  'oddHeader',
#  'page_margins',
#  'page_setup',
#  'parent',
#  'path',
#  'print_area',
#  'print_options',
#  'print_title_cols',
#  'print_title_rows',
#  'print_titles',
#  'protection',
#  'row_breaks',
#  'row_dimensions',
#  'rows',
#  'scenarios',
#  'selected_cell',
#  'set_printer_settings',
#  'sheet_format',
#  'sheet_properties',
#  'sheet_state',
#  'sheet_view',
#  'show_gridlines',
#  'tables',
#  'title',
#  'unmerge_cells',
#  'values',
#  'views']

# %%
#this will count the empty rows as well
sheet.max_row
# Out:
# 349

# %%
sheet.max_column
# Out:
# 49

# %%
#with this snippet of code we can get the real number of rows that are not emptyy!!
rows_num = sheet.max_row
last_row_with_data = 0
columns_num = sheet.max_column

num_nones = 0         #to track the number of None in a row
for i in reversed(range(rows_num)):
    for cell in sheet[i]:
        if cell.value is None:
            num_nones = num_nones + 1
            
    if(num_nones == columns_num):
        rows_num -= 1
        num_nones = 0
    else:
        last_row_with_data = rows_num
        break

print(last_row_with_data)
# Out:
# 304

# %%
#pulling out the content of each row
sheet_data = []
row_data = []
for i in range(last_row_with_data):
    row_list = list(sheet[i+1])
    row_data = []
    for cell in row_list:
        if cell.value is None:
            row_data.append('')
        else:
            row_data.append(cell.value)
    sheet_data.append(row_data)
print(sheet_data)
# Out:
# [['', 'TABLE 9. CHILD PROTECTION', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['', '', 'TABLEAU 9. PROTECTION DE L’ENFANT', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['', '', '', 'TABLA 9. PROTECCIÓN INFANTIL', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['', 'Countries and areas', '', '', 'Child labour (%)+\n2005–2012*', '', '', '', '', '', 'Child marriage (%)\n2005–2012*', '', '', '', 'Birth registration (%)+\n2005–2012*', '', 'Female genital mutilation/cutting (%)+\n2002–2012*', '', '', '', '', '', 'Justification of wife beating (%)\n 2005–2012*', '', '', '', 'Violent discipline (%)+\n2005–2012*', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'prevalence', '', '', '', 'attitudes', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['', '', '', '', 'total', '', 'male', '', 'female', '', 'married by 15', '', 'married by 18', '', 'total', '', 'womena  ', '', 'girlsb ', '', 'support for the practicec', '', 'male', '', 'female', '', 'total', '', 'male', '', 'female', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['', 'FRENCH HEADINGS', 'Pays et zones', '', 'Travail des enfants (%)+\n2005–2012*', '', '', '', '', '', 'Mariage d’enfants (%)\n2005–2012*', '', '', '', 'Enregistrement\ndes naissances\n(%)+\n2005–2012*\n', '', 'Mutilations génitales féminines/excision (%)+\n2002–2012*', '', '', '', '', '', 'Justification de la\nviolence conjugale (%)\n2005–2012*', '', '', '', 'Discipline imposée par la violence (%)+\n2005–2012*', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'prévalence', '', '', '', 'attitudes', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['', '', '', '', 'total', '', 'garçons', '', 'filles', '', 'marié à  15 ans\n', '', 'marié à  18 ans', '', 'total', '', 'femmes a  ', '', 'filles b ', '', 'soutien à cette pratique c', '', 'hommes', '', 'femmes', '', 'total', '', 'garçons', '', 'filles', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['', 'SPANISH HEADINGS', '', 'Países y zonas', 'Trabajo infantil (%)+ 2005–2012*', '', '', '', '', '', 'Matrimonio precoz (%) 2005–2012*', '', '', '', 'Inscripción del\nnacimiento (%) + 2005–2012*', '', 'Mutilación/excisión genital (%)+\n2002–2012*', '', '', '', '', '', 'Justificación de golpear\na la mujer (%)\n2005–2012*', '', '', '', 'Disciplina violenta (%)+  2005–2012*', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'prevalencia', '', '', '', 'actitudes', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['', '', '', '', 'total', '', 'hombre', '', 'mujer', '', 'casados a los 15 años', '', 'casados a los 18 años', '', 'total', '', 'Mujeresa  ', '', 'hijasb ', '', 'apoyo a la prácticac', '', 'hombre', '', 'mujer', '', 'total', '', 'hombre', '', 'mujer', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['', '', 'FRENCH COUNTRY NAMES', 'SPANISH COUNTRY NAMES', '', '', '', '', '', '', '', '', ...

# %%
# this is a script to parse child labor and child marriage data
data = {}
    
for i in range(14, last_row_with_data):
    # Start at 14th row, because that is where the country data begins
    row = sheet_data[i]
    country = row[1]
    if country == 'Zimbabwe':
        break
        
    data[country] = {
        'child_labor' : {
            'total': [row[4], row[5]],
            'male': [row[6], row[7]],
            'female': [row[8], row[9]],
        },
        'child_marriage': {
            'married_by_15': [row[10], row[11]],
            'married_by_18': [row[12], row[13]],
        }
    }

    
# pprint.pprint(data)
pprint.pprint(data)
# Out:
# {'Afghanistan': {'child_labor': {'female': [9.6, ''],
#                                  'male': [11, ''],
#                                  'total': [10.3, '']},
#                  'child_marriage': {'married_by_15': [15, ''],
#                                     'married_by_18': [40.4, '']}},
#  'Albania': {'child_labor': {'female': [9.4, '  '],
#                              'male': [14.4, '  '],
#                              'total': [12, '  ']},
#              'child_marriage': {'married_by_15': [0.2, ''],
#                                 'married_by_18': [9.6, '']}},
#  'Algeria': {'child_labor': {'female': [3.9, 'y'],
#                              'male': [5.5, 'y'],
#                              'total': [4.7, 'y']},
#              'child_marriage': {'married_by_15': [0.1, ''],
#                                 'married_by_18': [1.8, '']}},
#  'Andorra': {'child_labor': {'female': ['–', '  '],
#                              'male': ['–', ' '],
#                              'total': ['– ', ' ']},
#              'child_marriage': {'married_by_15': ['–', ''],
#                                 'married_by_18': ['–', '']}},
#  'Angola': {'child_labor': {'female': [24.8, 'x'],
#                             'male': [22.1, 'x'],
#                             'total': [23.5, 'x']},
#             'child_marriage': {'married_by_15': ['–', ''],
#                                'married_by_18': ['–', '']}},
#  'Antigua and Barbuda': {'child_labor': {'female': ['–', '  '],
#                                          'male': ['–', ' '],
#                                          'total': ['–', ' ']},
#                          'child_marriage': {'married_by_15': ['–', ''],
#                                             'married_by_18': ['–', '']}},
#  'Argentina': {'child_labor': {'female': [5.2, 'y'],
#                                'male': [7.6, 'y'],
#                                'total': [6.5, 'y']},
#                'child_marriage': {'married_by_15': ['–', ''],
#                                   'married_by_18': ['–', '']}},
#  'Armenia': {'child_labor': {'female': [2.9, ''],
#                              'male': [4.7, ''],
#                              'total': [3.9, '']},
#              'child_marriage': {'married_by_15': [0, ''],
#                                 'married_by_18': [7.2, '']}},
#  'Australia': {'child_labor': {'female': ['–', '  '],
#                                'male': ['–', ' '],
#                                'total': ['–', ' ']},
#                'child_marriage': {'married_by_15': ['–', ''],
#                                   'married_by_18': ['–', '']}},
#  'Austria': {'child_labor': {'female': ['–', '  '],
#                              'male': ['–', ' '],
#                              'total': ['–', ' ']},
#              'child_marriage': {'married_by_15': ['–', ''],
#                                 'married_by_18': ['–', '']}},
#  'Azerbaijan': {'child_labor': {'female': [5.4, 'y'],
#                                 'male': [7.5, 'y'],
#                                 'total': [6.5, 'y']},
#                 'child_marriage': {'married_by_15': [0.7, ''],
#                                    'married_by_18': [12.2, '']}},
#  'Bahamas': {'child_labor': {'female': ['–', '  '],
#                              'male': ['–', ' '],
#                              'total': ['–', ' ']},
#              'child_marriage': {'married_by_15': ['–', ''],
#                                 'married_by_18': ['–', '']}},
#  'Bahrain': {'child_labor': {'female': [3, 'x'],
#                              'male': [6.3, 'x'],
#                              'total': [4.6, 'x']},
#              'child_marriage': {'married_by_15': ['–', ''],
#                                 'married_by_18': ['–', '']}},
#  'Bangladesh': {'child_labor': {'female': [8.1, '  '],
#                                 'male': [17.5, '  '],
#                                 'total': [12.8, '  ']},
#                 'child_marriage': {'married_by_15': [29.1, ''],
#                                    'married_by_18': [64.9, '']}},
#  'Barbados': {'child_labor': {'female': ['–', '  '],
#                               'male': ['–', ' '],
#                               'total': ['–', ' ']},
#               'child_marriage': {'married_by_15': ['–', ''],
#                                  'married_by_18': ['–', '']}},
#  'Belarus': {'child_labor': {'female': [1.5, '  '],
#                              'male': [1.3, '  '],
#                              'total': [1.4, '  ']},
#              'child_marriage': {'married_by_15': [0, ''],
#                                 'married_by_18': [3.2, '']}},
#  'Belgium': {'child_labor': {'female': ['–', '  '],
#                              'male': ['–', ' '],
#                              'total': ['–', ' ']},
#              'child_marriage': {'married_by_15': ['–', ''],
#                                 'married_by_18': ['–', '']}},
#  'Belize': {'child_labor': {'female': [5, '  '],
#                             'male': [6.7, '  '],
#                             'total': [5.8, '  ']},
#             'child_marriage': {'married_by_15': [3.4, ''],
#                                'married_by_18': [25.9, '']}},
#  'Benin': {'child_labor': {'female': [44.6, '  '],
#                            'male': [46.5, '  '],
#                            'total': [45.6, '  ']},
#            'child_marriage': {'married_by_15': [7.9, ''],
#                               'married_by_18': [34.4, '']}},
#  'Bhutan': {'child_labor': {'female': [3.1, ''],
#                             'male': [2.6, ''],
#                             'total': [2.9, '']},
#             'child_marriage': {'married_by_15': [6.2, ''],
#                                'married_by_18': [25.8, '']}},
#  'Bolivia (Plurinational State of)': {'child_labor': {'female': [24.4, 'y'],
#                                                       'male': [28.2, 'y'],
#                                                       'total': [26.4, 'y']},
#                                       'child_marriage': {'married_by_15': [3.2,
#                                                                            ''],
#                                                          'married_by_18': [21.7,
#                                                                            '']}},
#  'Bosnia and Herzegovina': {'child_labor': {'female': [3.9, '  '],
#                                             'male': [6.6, '  '],
#                                             'total': [5.3, '  ']},
#                             'child_marriage': {'married_by_15': [0.2, ''],
#                                                'married_by_18': [3.5, '']}},
#  'Botswana': {'child_labor': {'female': [7, 'y'],
#                               'male': [10.9, 'y'],
#                               'total': [9, 'y']},
#               'child_marriage': {'married_by_15': ['–', ''],
#                                  'married_by_18': ['–', '']}},
#  'Brazil': {'child_labor': {'female': [5.9, 'y'],
#                             'male': [11.2, 'y'],
#                             'total': [8.6, 'y']},
#             'child_marriage': {'married_by_15': [10.5, ''],
#                                'married_by_18': [35.6, '']}},
#  'Brunei Darussalam': {'child_labor': {'female': ['–', '  '],
#                                        'male': ['–', ' '],
#                                        'total': ['–', ' ']},
#                        'child_marriage': {'married_by_15': ['–', ''],
#                                           'married_by_18': ['–', '']}},
#  'Bulgaria': {'child_labor': {'female': ['–', '  '],
#                               'male': ['–', ' '],
#                               'total': ['–', ' ']},
#               'child_marriage': {'married_by_15': ['–', ''],
#                                  'married_by_18': ['–', '']}},
#  'Burkina Faso': {'child_labor': {'female': [36, ''],
#                                   'male': [42.3, ''],
#                                   'total': [39.2, '']},
#                   'child_marriage': {'married_by_15': [10.2, ''],
#                                      'married_by_18': [51.6, '']}},
#  'Burundi': {'child_labor': {'female': [27.1, '  '],
#                              'male': [25.5, '  '],
#                              'total': [26.3, '  ']},
#              'child_marriage': {'married_by_15': [2.5, ''],
#                                 'married_by_18': [20.4, '']}},
#  'Cabo Verde': {'child_labor': {'female': [2.5, 'x,y'],
#                                 'male': [3.7, 'x,y'],
#                                 'total': [3.2, 'x,y']},
#                 'child_marriage': {'married_by_15': [2.8, ''],
#                                    'married_by_18': [18, '']}},
#  'Cambodia': {'child_labor': {'female': [35.9, 'y'],
#                               'male': [36.4, 'y'],
#                               'total': [36.1, 'y']},
#               'child_marriage': {'married_by_15': [2.1, ''],
#                                  'married_by_18': [18.4, '']}},
#  'Cameroon': {'child_labor': {'female': [40.2, '  '],
#                               'male': [43.1, '  '],
#                               'total': [41.7, '  ']},
#               'child_marriage': {'married_by_15': [13.4, ''],
#                                  'married_by_18': [38.4, '']}},
#  'Canada': {'child_labor': {'female': ['–', '  '],
#                             'male': ['–', ' '],
#                             'total': ['–', ' ']},
#             'child_marriage': {'married_by_15': ['–', ''],
#                                'married_by_18': ['–', '']}},
#  'Central African Republic ': {'child_labor': {'female': [29.9, '  '],
#                                                'male': [27.2, '  '],
#                                                'total': [28.5, '  ']},
#                                'child_marriage': {'married_by_15': [29.1, ''],
#                                                   'married_by_18': [67.9, '']}},
#  'Chad': {'child_labor': {'female': [27.8, '  '],
#                           'male': [24.5, '  '],
#                           'total': [26.1, '  ']},
#           'child_marriage': {'married_by_15': [29, ''],
#                              'married_by_18': [68.1, '']}},
#  'Chile': {'child_labor': {'female': [2.4, 'x'],
#                            'male': [3.4, 'x'],
#                            'total': [2.9, 'x']},
#            'child_marriage': {'married_by_15': ['–', ''],
#                               'married_by_18': ['–', '']}},
#  'China': {'child_labor': {'female': ['–', '  '],
#                            'male': ['–', ' '],
#                            'total': ['–', ' ']},
#            'child_marriage': {'married_by_15': ['–', ''],
#                               'married_by_18': ['–', '']}},
#  'Colombia': {'child_labor': {'female': [8.9, 'y'],
#                               'male': [16.6, 'y'],
#                               'total': [13, 'y']},
#               'child_marriage': {'married_by_15': [5.6, ''],
#                                  'married_by_18': [23, '']}},
#  'Comoros': {'child_labor': {'female': [28, 'x'],
#                              'male': [26.4, 'x'],
#                              'total': [27.1, 'x']},
#              'child_marriage': {'married_by_15': ['–', ''],
#                                 'married_by_18': ['–', '']}},
#  'Congo': {'child_labor': {'female': [25.1, '  '],
#                            'male': [24.2, '  '],
#                            'total': [24.7, '  ']},
#            'child_marriage': {'married_by_15': [6.7, ''],
#                               'married_by_18': [33.3, '']}},
#  'Cook Islands': {'child_labor': {'female': ['–', '  '],
#                                   'male': ['–', ' '],
#                                   'total': ['–', ' ']},
#                   'child_marriage': {'married_by_15': ['–', ''],
#                                      'married_by_18': ['–', '']}},
#  'Costa Rica': {'child_labor': {'female': [3.4, 'x'],
#                                 'male': [6, 'x'],
#                                 'total': [4.7, 'x']},
#                 'child_marriage': {'married_by_15': ['–', ''],
#                                    'married_by_18': ['–', '']}},
#  'Croatia': {'child_labor': {'female': ['–', '  '],
#                              'male': ['–', ' '],
#                              'total': ['–', ' ']},
#              'child_marriage': {'married_by_15': ['–', ''],
#                                 'married_by_18': ['–', '']}},
#  'Cuba': {'child_labor': {'female': ['–', '  '],
#                           'male': ['–', ' '],
#                           'total': ['–', ' ']},
#           'child_marriage': {'married_by_15': [8.9, ''],
#                              'married_by_18': [40.4, '']}},
#  'Cyprus': {'child_labor': {'female': ['–', '  '],
#                             'male': ['–', ' '],
#                             'total': ['–', ' ']},
#             'child_marriage': {'married_by_15': ['–', ''],
#                                'married_by_18': ['–', '']}},
#  'Czech Republic': {'child_labor': {'female': ['–', '  '],
#                                     'male': ['–', ' '],
#                                     'total': ['–', ' ']},
#                     'child_marriage': {'married_by_15': ['–', ''],
#                                        'married_by_18': ['–', '']}},
#  "Côte d'Ivoire": {'child_labor': {'female': [28, '  '],
#                                    'male': [25, '  '],
#                                    'total': [26, '  ']},
#                    'child_marriage': {'married_by_15': [9.8, ''],
#                                       'married_by_18': [33.2, '']}},
#  "Democratic People's Republic of Korea": {'child_labor': {'female': ['–',
#                                                                       '  '],
#                                                            'male': ['–', ' '],
#                                                            'total': ['–', ' ']},
#                                            'child_marriage': {'married_by_15': ['–',
#                                                                                 ''],
#                                                               'married_by_18': ['–',
#                                                                                 '']}},
#  'Democratic Republic of the Congo': {'child_labor': {'female': [16.8, '  '],
#                                                       'male': [13.1, '  '],
#                                                       'total': [15, '  ']},
#                                       'child_marriage': {'married_by_15': [9.3,
#                                                                            ''],
#                                                          'married_by_18': [39.4,
#                                                                            '']}},
#  'Denmark': {'child_labor': {'female': ['–', '  '],
#                              'male': ['–', ' '],
#                              'total': ['–', ' ']},
#              'child_marriage': {'married_by_15': ['–', ''],
#                                 'married_by_18': ['–', '']}},
#  'Djibouti': {'child_labor': {'female': [7.7, '  '],
#                               'male': [7.6, '  '],
#                               'total': [7.7, '  ']},
#               'child_marriage': {'married_by_15': [1.8, ''],
#                                  'married_by_18': [5.4, '']}},
#  'Dominica': {'child_labor': {'female': ['–', '  '],
#                               'male': ['–', ' '],
#                               'total': ['–', ' ']},
#               'child_marriage': {'married_by_15': ['–', ''],
#                                  'married_by_18': ['–', '']}},
#  'Dominican Republic': {'child_labor': {'female': [7.9, '  '],
#                                         'male': [17.5, '  '],
#                                         'total': [12.9, '  ']},
#                         'child_marriage': {'married_by_15': [11.7, ''],
#                                            'married_by_18': [40.8, '']}},
#  'Ecuador': {'child_labor': {'female': [7.9, '  '],
#                              'male': [7.1, '  '],
#                              'total': [7.5, '  ']},
#              'child_marriage': {'married_by_15': [3.8, 'x'],
#                                 'married_by_18': [22.2, 'x']}},
#  'Egypt': {'child_labor': {'female': [4, 'y'],
#                            'male': [14.3, 'y'],
#                            'total': [9.3, 'y']},
#            'child_marriage': {'married_by_15': [2.2, ''],
#                               'married_by_18': [16.6, '']}},
#  'El Salvador': {'child_labor': {'female': ['–', ''],
#                                  'male': ['–', ''],
#                                  'total': [10.4, 'y']},
#                  'child_marriage': {'married_by_15': [5, ''],
#                                     'married_by_18': [25.4, '']}},
#  'Equatorial Guinea': {'child_labor': {'female': [27.6, 'x'],
#                                        'male': [27.9, 'x'],
#                                        'total': [27.8, 'x']},
#                        'child_marriage': {'married_by_15': ['–', ''],
#                                           'married_by_18': ['–', '']}},
#  'Eritrea': {'child_labor': {'female': ['–', '  '],
#                              'male': ['–', ' '],
#                              'total': ['–', ' ']},
#              'child_marriage': {'married_by_15': [19.6, 'x'],
#                                 'married_by_18': [47, 'x']}},
#  'Estonia': {'child_labor': {'female': ['–', '  '],
#                              'male': ['–', ' '],
#                              'total': ['–', ' ']},
#              'child_marriage': {'married_by_15': ['–', ''],
#                                 'married_by_18': ['–', '']}},
#  'Ethiopia': {'child_labor': {'female': [23.5, ''],
#                               'male': [31.1, ''],
#                               'total': [27.4, '']},
#               'child_marriage': {'married_by_15': [16.3, ''],
#                                  'married_by_18': [41, '']}},
#  'Fiji': {'child_labor': {'female': ['–', '  '],
#                           'male': ['–', ' '],
#                           'total': ['–', ' ']},
#           'child_marriage': {'married_by_15': ['–', ''],
#                              'married_by_18': ['–', '']}},
#  'Finland': {'child_labor': {'female': ['–', '  '],
#                              'male': ['–', ' '],
#                              'total': ['–', ' ']},
#              'child_marriage': {'married_by_15': ['–', ''],
#                                 'married_by_18': ['–', '']}},
#  'France': {'child_labor': {'female': ['–', '  '],
#                             'male': ['–', ' '],
#                             'total': ['–', ' ']},
#             'child_marriage': {'married_by_15': ['–', ''],
#                                'married_by_18': ['–', '']}},
#  'Gabon': {'child_labor': {'female': [11.6, '  '],
#                            'male': [15.4, ' '],
#                            'total': [13.4, ' ']},
#            'child_marriage': {'married_by_15': [5.6, ''],
#                               'married_by_18': [21.9, '']}},
#  'Gambia': {'child_labor': {'female': [17.5, '  '],
#                             'male': [20.9, '  '],
#                             'total': [19.2, '  ']},
#             'child_marriage': {'married_by_15': [7.3, ''],
#                                'married_by_18': [36.4, '']}},
#  'Georgia': {'child_labor': {'female': [16.6, '  '],
#                              'male': [20, '  '],
#                              'total': [18.4, '  ']},
#              'child_marriage': {'married_by_15': [1.1, ''],
#                                 'married_by_18': [14, '']}},
#  'Germany': {'child_labor': {'female': ['–', '  '],
#                              'male': ['–', ' '],
#                              'total': ['–', ' ']},
#              'child_marriage': {'married_by_15': ['–', ''],
#                                 'married_by_18': ['–', '']}},
#  'Ghana': {'child_labor': {'female': [34, '  '],
#                            'male': [33.8, '  '],
#                            'total': [33.9, '  ']},
#            'child_marriage': {'married_by_15': [5, ''],
#                               'married_by_18': [20.7, '']}},
#  'Greece': {'child_labor': {'female': ['–', '  '],
#                             'male': ['–', ' '],
#                             'total': ['–', ' ']},
#             'child_marriage': {'married_by_15': ['–', ''],
#                                'married_by_18': ['–', '']}},
#  'Grenada': {'child_labor': {'female': ['–', '  '],
#                              'male': ['–', ' '],
#                              'total': ['–', ' ']},
#              'child_marriage': {'married_by_15': ['–', ''],
#                                 'married_by_18': ['–', '']}},
#  'Guatemala': {'child_labor': {'female': [16.1, 'y'],
#                                'male': [35.1, 'y'],
#                                'total': [25.8, 'y']},
#                'child_marriage': {'married_by_15': [7.1, ''],
#                                   'married_by_18': [30.3, '']}},
#  'Guinea': {'child_labor': {'female': [40.1, 'y'],
#                             'male': [40, 'y'],
#                             'total': [40.1, 'y']},
#             'child_marriage': {'married_by_15': [19.8, ''],
#                                'married_by_18': [63.1, '']}},
#  'Guinea-Bissau': {'child_labor': {'female': [36.4, '  '],
#                                    'male': [39.5, '  '],
#                                    'total': [38, '  ']},
#                    'child_marriage': {'married_by_15': [6.5, ''],
#                                       'married_by_18': [22, '']}},
#  'Guyana': {'child_labor': {'female': [15.5, '  '],
#                             'male': [17.3, '  '],
#                             'total': [16.4, '  ']},
#             'child_marriage': {'married_by_15': [5.5, ''],
#                                'married_by_18': [23, '']}},
#  'Haiti': {'child_labor': {'female': [24.3, '  '],
#                            'male': [24.5, '  '],
#                            'total': [24.4, '  ']},
#            'child_marriage': {'married_by_15': [2.8, ''],
#                               'married_by_18': [17.5, '']}},
#  'Holy See': {'child_labor': {'female': ['–', '  '],
#                               'male': ['–', ' '],
#                               'total': ['–', ' ']},
#               'child_marriage': {'married_by_15': ['–', ''],
#                                  'married_by_18': ['–', '']}},
#  'Honduras': {'child_labor': {'female': [15, 'x'],
#                               'male': [16.1, 'x'],
#                               'total': [15.6, 'x']},
#               'child_marriage': {'married_by_15': [7.6, ''],
#                                  'married_by_18': [33.6, '']}},
#  'Hungary': {'child_labor': {'female': ['–', '  '],
#                              'male': ['–', ' '],
#                              'total': ['–', ' ']},
#              'child_marriage': {'married_by_15': ['–', ''],
#                                 'married_by_18': ['–', '']}},
#  'Iceland': {'child_labor': {'female': ['–', '  '],
#                              'male': ['–', ' '],
#                              'total': ['–', ' ']},
#              'child_marriage': {'married_by_15': ['–', ''],
#                                 'married_by_18': ['–', '']}},
#  'India': {'child_labor': {'female': [11.9, '  '],
#                            'male': [11.6, '  '],
#                            'total': [11.8, '  ']},
#            'child_marriage': {'married_by_15': [18.2, ''],
#                               'married_by_18': [47.4, '']}},
#  'Indonesia': {'child_labor': {'female': [5.8, 'y'],
#                                'male': [7.9, 'y'],
#                                'total': [6.9, 'y']},
#                'child_marriage': {'married_by_15': [3, ''],
#                                   'married_by_18': [17, '']}},
#  'Iran (Islamic Republic of)': {'child_labor': {'female': [10.2, 'y'],
#                                                 'male': [12.5, 'y'],
#                                                 'total': [11.4, 'y']},
#                                 'child_marriage': {'married_by_15': [2.7, ''],
#                                                    'married_by_18': [16.7,
#                                                                      '']}},
#  'Iraq': {'child_labor': {'female': [4, '  '],
#                           'male': [5.4, '  '],
#                           'total': [4.7, '  ']},
#           'child_marriage': {'married_by_15': [4.6, ''],
#                              'married_by_18': [24.3, '']}},
#  'Ireland': {'child_labor': {'female': ['–', '  '],
#                              'male': ['–', ' '],
#                              'total': ['–', ' ']},
#              'child_marriage': {'married_by_15': ['–', ''],
#                                 'married_by_18': ['–', '']}},
#  'Israel': {'child_labor': {'female': ['–', '  '],
#                             'male': ['–', ' '],
#                             'total': ['–', ' ']},
#             'child_marriage': {'married_by_15': ['–', ''],
#                                'married_by_18': ['–', '']}},
#  'Italy': {'child_labor': {'female': ['–', '  '],
#                            'male': ['–', ' '],
#                            'total': ['–', ' ']},
#            'child_marriage': {'married_by_15': ['–', ''],
#                               'married_by_18': ['–', '']}},
#  'Jamaica': {'child_labor': {'female': [5.4, '  '],
#                              'male': [6.8, '  '],
#                              'total': [6.1, '  ']},
#              'child_marriage': {'married_by_15': [0.6, ''],
#                                 'married_by_18': [8.6, '']}},
#  'Japan': {'child_labor': {'female': ['–', '  '],
#                            'male': ['–', ' '],
#                            'total': ['–', ' ']},
#            'child_marriage': {'married_by_15': ['–', ''],
#                               'married_by_18': ['–', '']}},
#  'Jordan': {'child_labor': {'female': [0.4, 'y'],
#                             'male': [3.2, 'y'],
#                             'total': [1.9, 'y']},
#             'child_marriage': {'married_by_15': [0.7, ''],
#                                'married_by_18': [10.2, '']}},
#  'Kazakhstan': {'child_labor': {'female': [2.1, '  '],
#                                 'male': [2.4, '  '],
#                                 'total': [2.2, '  ']},
#                 'child_marriage': {'married_by_15': [0.3, ''],
#                                    'married_by_18': [6.1, '']}},
#  'Kenya': {'child_labor': {'female': [25.2, 'x'],
#                            'male': [26.5, 'x'],
#                            'total': [25.9, 'x']},
#            'child_marriage': {'married_by_15': [6.2, ''],
#                               'married_by_18': [26.4, '']}},
#  'Kiribati': {'child_labor': {'female': ['–', '  '],
#                               'male': ['–', ' '],
#                               'total': ['–', ' ']},
#               'child_marriage': {'married_by_15': [2.8, ''],
#                                  'married_by_18': [20.3, '']}},
#  'Kuwait': {'child_labor': {'female': ['–', '  '],
#                             'male': ['–', ' '],
#                             'total': ['–', ' ']},
#             'child_marriage': {'married_by_15': ['–', ''],
#                                'married_by_18': ['–', '']}},
#  'Kyrgyzstan': {'child_labor': {'female': [2.9, '  '],
#                                 'male': [4.3, '  '],
#                                 'total': [3.6, '  ']},
#                 'child_marriage': {'married_by_15': [0.5, ''],
#                                    'married_by_18': [10.4, '']}},
#  "Lao People's Democratic Republic": {'child_labor': {'female': [11.2, 'y'],
#                                                       'male': [9, 'y'],
#                                                       'total': [10.1, 'y']},
#                                       'child_marriage': {'married_by_15': [8.9,
#                                                                            ''],
#                                                          'married_by_18': [35.4,
#                                                                            '']}},
#  'Latvia': {'child_labor': {'female': ['–', '  '],
#                             'male': ['–', ' '],
#                             'total': ['–', ' ']},
#             'child_marriage': {'married_by_15': ['–', ''],
#                                'married_by_18': ['–', '']}},
#  'Lebanon': {'child_labor': {'female': [0.9, '  '],
#                              'male': [2.7, '  '],
#                              'total': [1.9, '  ']},
#              'child_marriage': {'married_by_15': [1.2, ''],
#                                 'married_by_18': [6.1, '']}},
#  'Lesotho': {'child_labor': {'female': [20.7, 'x'],
#                              'male': [25, 'x'],
#                              'total': [22.9, 'x']},
#              'child_marriage': {'married_by_15': [2.3, ''],
#                                 'married_by_18': [18.8, '']}},
#  'Liberia': {'child_labor': {'female': [20.5, '  '],
#                              'male': [21.1, '  '],
#                              'total': [20.8, '  ']},
#              'child_marriage': {'married_by_15': [10.8, ''],
#                                 'married_by_18': [37.9, '']}},
#  'Libya': {'child_labor': {'female': ['–', '  '],
#                            'male': ['–', ' '],
#                            'total': ['–', ' ']},
#            'child_marriage': {'married_by_15': ['–', ''],
#                               'married_by_18': ['–', '']}},
#  'Liechtenstein': {'child_labor': {'female': ['–', '  '],
#                                    'male': ['–', ' '],
#                                    'total': ['–', ' ']},
#                    'child_marriage': {'married_by_15': ['–', ''],
#                                       'married_by_18': ['–', '']}},
#  'Lithuania': {'child_labor': {'female': ['–', '  '],
#                                'male': ['–', ' '],
#                                'total': ['–', ' ']},
#                'child_marriage': {'married_by_15': ['–', ''],
#                                   'married_by_18': ['–', '']}},
#  'Luxembourg': {'child_labor': {'female': ['–', '  '],
#                                 'male': ['–', ' '],
#                                 'total': ['–', ' ']},
#                 'child_marriage': {'married_by_15': ['–', ''],
#                                    'married_by_18': ['–', '']}},
#  'Madagascar': {'child_labor': {'female': [26.7, 'y'],
#                                 'male': [29.4, 'y'],
#                                 'total': [28.1, 'y']},
#                 'child_marriage': {'married_by_15': [14.4, ''],
#                                    'married_by_18': [48.2, '']}},
#  'Malawi': {'child_labor': {'female': [26.2, '  '],
#                             'male': [25.3, '  '],
#                             'total': [25.7, '  ']},
#             'child_marriage': {'married_by_15': [11.7, ''],
#                                'married_by_18': [49.6, '']}},
#  'Malaysia': {'child_labor': {'female': ['–', '  '],
#                               'male': ['–', ' '],
#                               'total': ['–', ' ']},
#               'child_marriage': {'married_by_15': ['–', ''],
#                                  'married_by_18': ['–', '']}},
#  'Maldives': {'child_labor': {'female': ['–', '  '],
#                               'male': ['–', ' '],
#                               'total': ['–', ' ']},
#               'child_marriage': {'married_by_15': [0.3, ''],
#                                  'married_by_18': [3.9, '']}},
#  'Mali': {'child_labor': {'female': [20.7, '  '],
#                           'male': [22, '  '],
#                           'total': [21.4, '  ']},
#           'child_marriage': {'married_by_15': [14.5, ''],
#                              'married_by_18': [55, '']}},
#  'Malta': {'child_labor': {'female': ['–', '  '],
#                            'male': ['–', ' '],
#                            'total': ['–', ' ']},
#            'child_marriage': {'married_by_15': ['–', ''],
#                               'married_by_18': ['–', '']}},
#  'Marshall Islands': {'child_labor': {'female': ['–', '  '],
#                                       'male': ['–', ' '],
#                                       'total': ['–', ' ']},
#                       'child_marriage': {'married_by_15': [5.6, ''],
#                                          'married_by_18': [26.3, '']}},
#  'Mauritania': {'child_labor': {'female': [14.9, ''],
#                                 'male': [14.3, ''],
#                                 'total': [14.6, '']},
#                 'child_marriage': {'married_by_15': [14.2, ''],
#                                    'married_by_18': [34.3, '']}},
#  'Mauritius': {'child_labor': {'female': ['–', '  '],
#                                'male': ['–', ' '],
#                                'total': ['–', ' ']},
#                'child_marriage': {'married_by_15': ['–', ''],
#                                   'married_by_18': ['–', '']}},
#  'Mexico': {'child_labor': {'female': [5.3, 'y'],
#                             'male': [7.3, 'y'],
#                             'total': [6.3, 'y']},
#             'child_marriage': {'married_by_15': [5.1, ''],
#                                'married_by_18': [22.9, '']}},
#  'Micronesia (Federated States of)': {'child_labor': {'female': ['–', '  '],
#                                                       'male': ['–', ' '],
#                                                       'total': ['–', ' ']},
#                                       'child_marriage': {'married_by_15': ['–',
#                                                                            ''],
#                                                          'married_by_18': ['–',
#                                                                            '']}},
#  'Monaco': {'child_labor': {'female': ['–', '  '],
#                             'male': ['–', ' '],
#                             'total': ['–', ' ']},
#             'child_marriage': {'married_by_15': ['–', ''],
#                                'married_by_18': ['–', '']}},
#  'Mongolia': {'child_labor': {'female': [10.6, '  '],
#                               'male': [10.3, '  '],
#                               'total': [10.4, '  ']},
#               'child_marriage': {'married_by_15': [0.1, ''],
#                                  'married_by_18': [4.7, '']}},
#  'Montenegro': {'child_labor': {'female': [7.8, '  '],
#                                 'male': [11.7, '  '],
#                                 'total': [9.9, '  ']},
#                 'child_marriage': {'married_by_15': [0.2, ''],
#                                    'married_by_18': [4.8, '']}},
#  'Morocco': {'child_labor': {'female': [7.5, '  '],
#                              'male': [9.1, '  '],
#                              'total': [8.3, '  ']},
#              'child_marriage': {'married_by_15': [2.5, 'x'],
#                                 'married_by_18': [15.9, 'x']}},
#  'Mozambique': {'child_labor': {'female': [23.8, '  '],
#                                 'male': [20.5, '  '],
#                                 'total': [22.2, '  ']},
#                 'child_marriage': {'married_by_15': [14.3, ''],
#                                    'married_by_18': [48.2, '']}},
#  'Myanmar': {'child_labor': {'female': ['–', '  '],
#                              'male': ['–', ' '],
#                              'total': ['–', ' ']},
#              'child_marriage': {'married_by_15': ['–', ''],
#                                 'married_by_18': ['–', '']}},
#  'Namibia': {'child_labor': {'female': ['–', ''],
#                              'male': ['–', ''],
#                              'total': ['–', '']},
#              'child_marriage': {'married_by_15': [2.4, ''],
#                                 'married_by_18': [8.6, '']}},
#  'Nauru': {'child_labor': {'female': ['–', '  '],
#                            'male': ['–', ' '],
#                            'total': ['–', ' ']},
#            'child_marriage': {'married_by_15': [1.9, ''],
#                               'married_by_18': [26.8, '']}},
#  'Nepal': {'child_labor': {'female': [37.8, 'y'],
#                            'male': [30.2, 'y'],
#                            'total': [33.9, 'y']},
#            'child_marriage': {'married_by_15': [10.1, ''],
#                               'married_by_18': [40.7, '']}},
#  'Netherlands': {'child_labor': {'female': ['–', '  '],
#                                  'male': ['–', ' '],
#                                  'total': ['–', ' ']},
#                  'child_marriage': {'married_by_15': ['–', ''],
#                                     'married_by_18': ['–', '']}},
#  'New Zealand': {'child_labor': {'female': ['–', '  '],
#                                  'male': ['–', ' '],
#                                  'total': ['–', ' ']},
#                  'child_marriage': {'married_by_15': ['–', ''],
#                                     'married_by_18': ['–', '']}},
#  'Nicaragua': {'child_labor': {'female': [11.2, 'x'],
#                                'male': [17.6, 'x'],
#                                'total': [14.5, 'x']},
#                'child_marriage': {'married_by_15': [10.4, ''],
#                                   'married_by_18': [40.6, '']}},
#  'Niger': {'child_labor': {'female': [42.9, '  '],
#                            'male': [42.7, '  '],
#                            'total': [42.8, '  ']},
#            'child_marriage': {'married_by_15': [36.1, ''],
#                               'married_by_18': [74.5, '']}},
#  'Nigeria': {'child_labor': {'female': [25.3, '  '],
#                              'male': [24.1, ' '],
#                              'total': [24.7, '']},
#              'child_marriage': {'married_by_15': [19.6, ''],
#                                 'married_by_18': [39, '']}},
#  'Niue': {'child_labor': {'female': ['–', '  '],
#                           'male': ['–', ' '],
#                           'total': ['–', ' ']},
#           'child_marriage': {'married_by_15': ['–', ''],
#                              'married_by_18': ['–', '']}},
#  'Norway': {'child_labor': {'female': ['–', '  '],
#                             'male': ['–', ' '],
#                             'total': ['–', ' ']},
#             'child_marriage': {'married_by_15': ['–', ''],
#                                'married_by_18': ['–', '']}},
#  'Oman': {'child_labor': {'female': ['–', '  '],
#                           'male': ['–', ' '],
#                           'total': ['–', ' ']},
#           'child_marriage': {'married_by_15': ['–', ''],
#                              'married_by_18': ['–', '']}},
#  'Pakistan': {'child_labor': {'female': ['–', '  '],
#                               'male': ['–', ' '],
#                               'total': ['–', ' ']},
#               'child_marriage': {'married_by_15': [6.7, ''],
#                                  'married_by_18': [24, '']}},
#  'Palau': {'child_labor': {'female': ['–', '  '],
#                            'male': ['–', ' '],
#                            'total': ['–', ' ']},
#            'child_marriage': {'married_by_15': ['–', ''],
#                               'married_by_18': ['–', '']}},
#  'Panama': {'child_labor': {'female': [3, 'y'],
#                             'male': [8, 'y'],
#                             'total': [5.6, 'y']},
#             'child_marriage': {'married_by_15': ['–', ''],
#                                'married_by_18': ['–', '']}},
#  'Papua New Guinea': {'child_labor': {'female': ['–', '  '],
#                                       'male': ['–', ' '],
#                                       'total': ['–', ' ']},
#                       'child_marriage': {'married_by_15': [2.1, ''],
#                                          'married_by_18': [21.3, '']}},
#  'Paraguay': {'child_labor': {'female': [12.2, 'x'],
#                               'male': [16.8, 'x'],
#                               'total': [14.6, 'x']},
#               'child_marriage': {'married_by_15': ['–', ''],
#                                  'married_by_18': [17.9, 'x']}},
#  'Peru': {'child_labor': {'female': [36.3, 'y'],
#                           'male': [30.6, 'y'],
#                           'total': [33.5, 'y']},
#           'child_marriage': {'married_by_15': [2.5, ''],
#                              'married_by_18': [19.1, '']}},
#  'Philippines': {'child_labor': {'female': ['–', '  '],
#                                  'male': ['–', '  '],
#                                  'total': ['–', '  ']},
#                  'child_marriage': {'married_by_15': [2.1, ''],
#                                     'married_by_18': [14.2, '']}},
#  'Poland': {'child_labor': {'female': ['–', '  '],
#                             'male': ['–', ' '],
#                             'total': ['–', ' ']},
#             'child_marriage': {'married_by_15': ['–', ''],
#                                'married_by_18': ['–', '']}},
#  'Portugal': {'child_labor': {'female': [2.5, 'x,y'],
#                               'male': [4.2, 'x,y'],
#                               'total': [3.4, 'x,y']},
#               'child_marriage': {'married_by_15': ['–', ''],
#                                  'married_by_18': ['–', '']}},
#  'Qatar': {'child_labor': {'female': ['–', '  '],
#                            'male': ['–', ' '],
#                            'total': ['–', ' ']},
#            'child_marriage': {'married_by_15': ['–', ''],
#                               'married_by_18': ['–', '']}},
#  'Republic of Korea': {'child_labor': {'female': ['–', '  '],
#                                        'male': ['–', ' '],
#                                        'total': ['–', ' ']},
#                        'child_marriage': {'married_by_15': ['–', ''],
#                                           'married_by_18': ['–', '']}},
#  'Republic of Moldova': {'child_labor': {'female': [12.3, '  '],
#                                          'male': [20.2, '  '],
#                                          'total': [16.3, '  ']},
#                          'child_marriage': {'married_by_15': [0.5, ''],
#                                             'married_by_18': [18.9, '']}},
#  'Romania': {'child_labor': {'female': [0.7, 'x'],
#                              'male': [1.2, 'x'],
#                              'total': [0.9, 'x']},
#              'child_marriage': {'married_by_15': ['–', ''],
#                                 'married_by_18': ['–', '']}},
#  'Russian Federation': {'child_labor': {'female': ['–', '  '],
#                                         'male': ['–', ' '],
#                                         'total': ['–', ' ']},
#                         'child_marriage': {'married_by_15': ['–', ''],
#                                            'married_by_18': ['–', '']}},
#  'Rwanda': {'child_labor': {'female': [30.4, '  '],
#                             'male': [26.7, '  '],
#                             'total': [28.5, '  ']},
#             'child_marriage': {'married_by_15': [0.8, ''],
#                                'married_by_18': [8.1, '']}},
#  'Saint Kitts and Nevis': {'child_labor': {'female': ['–', '  '],
#                                            'male': ['–', ' '],
#                                            'total': ['–', ' ']},
#                            'child_marriage': {'married_by_15': ['–', ''],
#                                               'married_by_18': ['–', '']}},
#  'Saint Lucia': {'child_labor': {'female': ['–', '  '],
#                                  'male': ['–', ' '],
#                                  'total': ['–', ' ']},
#                  'child_marriage': {'married_by_15': ['–', ''],
#                                     'married_by_18': ['–', '']}},
#  'Saint Vincent and the Grenadines': {'child_labor': {'female': ['–', '  '],
#                                                       'male': ['–', ' '],
#                                                       'total': ['–', ' ']},
#                                       'child_marriage': {'married_by_15': ['–',
#                                                                            ''],
#                                                          'married_by_18': ['–',
#                                                                            '']}},
#  'Samoa': {'child_labor': {'female': ['–', '  '],
#                            'male': ['–', ' '],
#                            'total': ['–', ' ']},
#            'child_marriage': {'married_by_15': ['–', ''],
#                               'married_by_18': ['–', '']}},
#  'San Marino': {'child_labor': {'female': ['–', '  '],
#                                 'male': ['–', ' '],
#                                 'total': ['–', ' ']},
#                 'child_marriage': {'married_by_15': ['–', ''],
#                                    'married_by_18': ['–', '']}},
#  'Sao Tome and Principe': {'child_labor': {'female': [7.2, '  '],
#                                            'male': [7.7, '  '],
#                                            'total': [7.5, '  ']},
#                            'child_marriage': {'married_by_15': [5, ''],
#                                               'married_by_18': [34.4, '']}},
#  'Saudi Arabia': {'child_labor': {'female': ['–', '  '],
#                                   'male': ['–', ' '],
#                                   'total': ['–', ' ']},
#                   'child_marriage': {'married_by_15': ['–', ''],
#                                      'married_by_18': ['–', '']}},
#  'Senegal': {'child_labor': {'female': [15.6, ''],
#                              'male': [17.5, ''],
#                              'total': [16.5, '']},
#              'child_marriage': {'married_by_15': [12, ''],
#                                 'married_by_18': [32.9, '']}},
#  'Serbia': {'child_labor': {'female': [4.4, '  '],
#                             'male': [4.5, '  '],
#                             'total': [4.4, '  ']},
#             'child_marriage': {'married_by_15': [0.9, ''],
#                                'married_by_18': [5, '']}},
#  'Seychelles': {'child_labor': {'female': ['–', '  '],
#                                 'male': ['–', ' '],
#                                 'total': ['–', ' ']},
#                 'child_marriage': {'married_by_15': ['–', ''],
#                                    'married_by_18': ['–', '']}},
#  'Sierra Leone': {'child_labor': {'female': [25, '  '],
#                                   'male': [27, '  '],
#                                   'total': [26, '  ']},
#                   'child_marriage': {'married_by_15': [17.7, ''],
#                                      'married_by_18': [43.7, '']}},
#  'Singapore': {'child_labor': {'female': ['–', '  '],
#                                'male': ['–', ' '],
#                                'total': ['–', ' ']},
#                'child_marriage': {'married_by_15': ['–', ''],
#                                   'married_by_18': ['–', '']}},
#  'Slovakia': {'child_labor': {'female': ['–', '  '],
#                               'male': ['–', ' '],
#                               'total': ['–', ' ']},
#               'child_marriage': {'married_by_15': ['–', ''],
#                                  'married_by_18': ['–', '']}},
#  'Slovenia': {'child_labor': {'female': ['–', '  '],
#                               'male': ['–', ' '],
#                               'total': ['–', ' ']},
#               'child_marriage': {'married_by_15': ['–', ''],
#                                  'married_by_18': ['–', '']}},
#  'Solomon Islands': {'child_labor': {'female': ['–', '  '],
#                                      'male': ['–', ' '],
#                                      'total': ['–', ' ']},
#                      'child_marriage': {'married_by_15': [3.1, ''],
#                                         'married_by_18': [22.4, '']}},
#  'Somalia': {'child_labor': {'female': [53.6, '  '],
#                              'male': [44.5, '  '],
#                              'total': [49, '  ']},
#              'child_marriage': {'married_by_15': [8.4, ''],
#                                 'married_by_18': [45.3, '']}},
#  'South Africa': {'child_labor': {'female': ['–', '  '],
#                                   'male': ['–', ' '],
#                                   'total': ['–', ' ']},
#                   'child_marriage': {'married_by_15': [0.8, 'x'],
#                                      'married_by_18': [5.6, 'x']}},
#  'South Sudan': {'child_labor': {'female': ['–', ''],
#                                  'male': ['–', ''],
#                                  'total': ['–', '']},
#                  'child_marriage': {'married_by_15': [8.9, ''],
#                                     'married_by_18': [51.5, '']}},
#  'Spain': {'child_labor': {'female': ['–', '  '],
#                            'male': ['–', ' '],
#                            'total': ['–', ' ']},
#            'child_marriage': {'married_by_15': ['–', ''],
#                               'married_by_18': ['–', '']}},
#  'Sri Lanka': {'child_labor': {'female': ['–', '  '],
#                                'male': ['–', '  '],
#                                'total': ['–', '  ']},
#                'child_marriage': {'married_by_15': [1.7, ''],
#                                   'married_by_18': [11.8, '']}},
#  'State of Palestine': {'child_labor': {'female': [4, '  '],
#                                         'male': [7.4, ' '],
#                                         'total': [5.7, ' ']},
#                         'child_marriage': {'married_by_15': [2.2, ''],
#                                            'married_by_18': [20.6, '']}},
#  'Sudan': {'child_labor': {'female': ['–', ''],
#                            'male': ['–', ''],
#                            'total': ['–', '']},
#            'child_marriage': {'married_by_15': [7.2, ''],
#                               'married_by_18': [32.9, '']}},
#  'Suriname': {'child_labor': {'female': [4.1, '  '],
#                               'male': [4.1, '  '],
#                               'total': [4.1, '  ']},
#               'child_marriage': {'married_by_15': [5.2, ''],
#                                  'married_by_18': [18.8, '']}},
#  'Swaziland': {'child_labor': {'female': [6.9, '  '],
#                                'male': [7.7, '  '],
#                                'total': [7.3, '  ']},
#                'child_marriage': {'married_by_15': [0.7, ''],
#                                   'married_by_18': [6.5, '']}},
#  'Sweden': {'child_labor': {'female': ['–', '  '],
#                             'male': ['–', ' '],
#                             'total': ['–', ' ']},
#             'child_marriage': {'married_by_15': ['–', ''],
#                                'married_by_18': ['–', '']}},
#  'Switzerland': {'child_labor': {'female': ['–', '  '],
#                                  'male': ['–', ' '],
#                                  'total': ['–', ' ']},
#                  'child_marriage': {'married_by_15': ['–', ''],
#                                     'married_by_18': ['–', '']}},
#  'Syrian Arab Republic': {'child_labor': {'female': [3, '  '],
#                                           'male': [5, '  '],
#                                           'total': [4, '  ']},
#                           'child_marriage': {'married_by_15': [2.5, ''],
#                                              'married_by_18': [13.3, '']}},
#  'Tajikistan': {'child_labor': {'female': [10.6, '  '],
#                                 'male': [9.4, '  '],
#                                 'total': [10, '  ']},
#                 'child_marriage': {'married_by_15': [1, ''],
#                                    'married_by_18': [12.7, '']}},
#  'Thailand': {'child_labor': {'female': [8.2, '  '],
#                               'male': [8.3, '  '],
#                               'total': [8.3, '  ']},
#               'child_marriage': {'married_by_15': [2.8, ''],
#                                  'married_by_18': [19.6, '']}},
#  'The former Yugoslav Republic of Macedonia': {'child_labor': {'female': [13,
#                                                                           '  '],
#                                                                'male': [12.1,
#                                                                         '  '],
#                                                                'total': [12.5,
#                                                                          '  ']},
#                                                'child_marriage': {'married_by_15': [0.9,
#                                                                                     ''],
#                                                                   'married_by_18': [6.9,
#                                                                                     '']}},
#  'Timor-Leste': {'child_labor': {'female': [4.4, 'x'],
#                                  'male': [4.1, 'x'],
#                                  'total': [4.2, 'x']},
#                  'child_marriage': {'married_by_15': [3, ''],
#                                     'married_by_18': [18.9, '']}},
#  'Togo': {'child_labor': {'female': [28.9, '  '],
#                           'male': [27.7, '  '],
#                           'total': [28.3, '  ']},
#           'child_marriage': {'married_by_15': [5.8, ''],
#                              'married_by_18': [25.2, '']}},
#  'Tonga': {'child_labor': {'female': ['–', '  '],
#                            'male': ['–', ' '],
#                            'total': ['–', ' ']},
#            'child_marriage': {'married_by_15': ['–', ''],
#                               'married_by_18': ['–', '']}},
#  'Trinidad and Tobago': {'child_labor': {'female': [0.6, '  '],
#                                          'male': [0.7, '  '],
#                                          'total': [0.7, '  ']},
#                          'child_marriage': {'married_by_15': [1.8, ''],
#                                             'married_by_18': [8.1, '']}},
#  'Tunisia': {'child_labor': {'female': [1.6, '  '],
#                              'male': [2.6, ' '],
#                              'total': [2.1, ' ']},
#              'child_marriage': {'married_by_15': [0, ''],
#                                 'married_by_18': [1.6, '']}},
#  'Turkey': {'child_labor': {'female': [1.8, 'y'],
#                             'male': [3.3, 'y'],
#                             'total': [2.6, 'y']},
#             'child_marriage': {'married_by_15': [2.5, ''],
#                                'married_by_18': [14, '']}},
#  'Turkmenistan': {'child_labor': {'female': ['–', '  '],
#                                   'male': ['–', ' '],
#                                   'total': ['–', ' ']},
#                   'child_marriage': {'married_by_15': [0.6, ''],
#                                      'married_by_18': [7.3, '']}},
#  'Tuvalu': {'child_labor': {'female': ['–', '  '],
#                             'male': ['–', ' '],
#                             'total': ['–', ' ']},
#             'child_marriage': {'married_by_15': [0, ''],
#                                'married_by_18': [9.9, '']}},
#  'Uganda': {'child_labor': {'female': [23.7, 'y'],
#                             'male': [26.9, 'y'],
#                             'total': [25.4, 'y']},
#             'child_marriage': {'married_by_15': [9.9, ''],
#                                'married_by_18': [39.7, '']}},
#  'Ukraine': {'child_labor': {'female': [6.7, '  '],
#                              'male': [7.9, '  '],
#                              'total': [7.3, '  ']},
#              'child_marriage': {'married_by_15': [0.2, ''],
#                                 'married_by_18': [9.9, '']}},
#  'United Arab Emirates': {'child_labor': {'female': ['–', '  '],
#                                           'male': ['–', ' '],
#                                           'total': ['–', ' ']},
#                           'child_marriage': {'married_by_15': ['–', ''],
#                                              'married_by_18': ['–', '']}},
#  'United Kingdom': {'child_labor': {'female': ['–', '  '],
#                                     'male': ['–', ' '],
#                                     'total': ['–', ' ']},
#                     'child_marriage': {'married_by_15': ['–', ''],
#                                        'married_by_18': ['–', '']}},
#  'United Republic of Tanzania': {'child_labor': {'female': [18.8, 'y'],
#                                                  'male': [23.3, 'y'],
#                                                  'total': [21.1, 'y']},
#                                  'child_marriage': {'married_by_15': [6.6, ''],
#                                                     'married_by_18': [36.9,
#                                                                       '']}},
#  'United States': {'child_labor': {'female': ['–', '  '],
#                                    'male': ['–', ' '],
#                                    'total': ['–', ' ']},
#                    'child_marriage': {'married_by_15': ['–', ''],
#                                       'married_by_18': ['–', '']}},
#  'Uruguay': {'child_labor': {'female': [7.5, 'y'],
#                              'male': [8.3, 'y'],
#                              'total': [7.9, 'y']},
#              'child_marriage': {'married_by_15': ['–', ''],
#                                 'married_by_18': ['–', '']}},
#  'Uzbekistan': {'child_labor': {'female': ['–', '  '],
#                                 'male': ['–', ' '],
#                                 'total': ['–', ' ']},
#                 'child_marriage': {'married_by_15': [0.3, ''],
#                                    'married_by_18': [7.2, '']}},
#  'Vanuatu': {'child_labor': {'female': ['–', '  '],
#                              'male': ['–', ' '],
#                              'total': ['–', ' ']},
#              'child_marriage': {'married_by_15': [8.8, ''],
#                                 'married_by_18': [27.1, '']}},
#  'Venezuela (Bolivarian Republic of)': {'child_labor': {'female': [6.2, 'x'],
#                                                         'male': [9.2, 'x'],
#                                                         'total': [7.7, 'x']},
#                                         'child_marriage': {'married_by_15': ['–',
#                                                                              ''],
#                                                            'married_by_18': ['–',
#                                                                              '']}},
#  'Viet Nam': {'child_labor': {'female': [7.4, '  '],
#                               'male': [6.5, '  '],
#                               'total': [6.9, '  ']},
#               'child_marriage': {'married_by_15': [0.5, ''],
#                                  'married_by_18': [9.3, '']}},
#  'Yemen': {'child_labor': {'female': [24.4, '  '],
#                            'male': [21.1, '  '],
#                            'total': [22.7, '  ']},
#            'child_marriage': {'married_by_15': [12, ''],
#                               'married_by_18': [32.3, '']}},
#  'Zambia': {'child_labor': {'female': [39.5, 'y'],
#                             'male': [41.6, 'y'],
#                             'total': [40.6, 'y']},
#             'child_marriage': {'married_by_15': [8.5, ''],
#                                'married_by_18': [41.6, '']}}}
